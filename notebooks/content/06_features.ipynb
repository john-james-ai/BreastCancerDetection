# %% [markdown]
# # CBIS-DDSM Feature Engineering
# The CBIS-DDSM has 45 calcification types, 9 calcification distributions, 20 mass shapes, and 19 mass margins. Many of which are compound categories, in that two or more categories are combined. For instance, calcification type 'ROUND_AND_REGULAR-PUNCTATE-AMORPHOUS' indicates three different types: 'ROUND_AND_REGULAR', 'PUNCTATE', and 'AMORPHOUS'. This section will separate these compound categories into separate groups, one-hot encode them, and persist the data in separate datasets for downstream analysis.

# %%
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))

import pandas as pd
import numpy as np
pd.options.display.max_columns = 99

# %%
FP_IN = "data/clean/cases.csv"
FP_OUT = "data/clean/cases_enc.csv"

# %%
CALC_TYPES = ["AMORPHOUS","COARSE","DYSTROPHIC","EGGSHELL","FINE_LINEAR_BRANCHING","LARGE_RODLIKE","LUCENT_CENTERED",
"MILK_OF_CALCIUM","PLEOMORPHIC","PUNCTATE","ROUND_AND_REGULAR","SKIN","VASCULAR"]
CALC_DISTRIBUTIONS = ["CLUSTERED","LINEAR","REGIONAL","DIFFUSELY_SCATTERED","SEGMENTAL"]
MASS_SHAPES = ["IRREGULAR","ARCHITECTURAL_DISTORTION","OVAL","LYMPH_NODE","LOBULATED","FOCAL_ASYMMETRIC_DENSITY","ROUND","ASYMMETRIC_BREAST_TISSUE"]
MASS_MARGINS = ["SPICULATED","ILL_DEFINED","CIRCUMSCRIBED","OBSCURED","MICROLOBULATED"]
MORPHOLOGY = {'calc_type': {'prefix': 'CT','values': CALC_TYPES}, 'calc_distribution': {'prefix': 'CD', 'values': CALC_DISTRIBUTIONS},'mass_shape': {'prefix': 'MS','values': MASS_SHAPES}, 'mass_margins': {'prefix': 'MM', 'values': MASS_MARGINS}}

# %%
def encode_column(df, prefix, col, value):
    newcol = prefix + '_' + value
    df[newcol] = np.where(df[col].str.contains(value),1,0)
    return df

# %%
def encode_dataset(df: pd.DataFrame, morphology: dict) -> pd.DataFrame:
    for feature, data in morphology.items():
        for value in data['values']:
            df = encode_column(df=df, prefix=data['prefix'], col=feature, value=value)
    return df

# %%
df = pd.read_csv(FP_IN)
df = encode_dataset(df=df, morphology=MORPHOLOGY)
df.info()
df.sample(10)
df.to_csv(FP_OUT, index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3566 entries, 0 to 3565
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   patient_id                   3566 non-null   object
#  1   breast_density               3566 non-null   int64
#  2   left_or_right_breast         3566 non-null   object
#  3   image_view                   3566 non-null   object
#  4   abnormality_id               3566 non-null   int64
#  5   abnormality_type             3566 non-null   object
#  6   calc_type                    3566 non-null   object
#  7   calc_distribution            3566 non-null   object
#  8   assessment                   3566 non-null   int64
#  9   pathology                    3566 non-null   object
#  10  subtlety                     3566 non-null   int64
#  11  fileset                      3566 non-null   object
#  12  mass_shape                   3566 non-null   object
#  13  mass_margins                 3566 non-null   object
#  14  case_id                      3566 non-null   object
#  15  cancer                       3566 non-null   bool
#  16  CT_AMORPHOUS                 3566 non-null   int64
#  17  CT_COARSE                    3566 non-null   int64
#  18  CT_DYSTROPHIC                3566 non-null   int64
#  19  CT_EGGSHELL                  3566 non-null   int64
#  20  CT_FINE_LINEAR_BRANCHING     3566 non-null   int64
#  21  CT_LARGE_RODLIKE             3566 non-null   int64
#  22  CT_LUCENT_CENTERED           3566 non-null   int64
#  23  CT_MILK_OF_CALCIUM           3566 non-null   int64
#  24  CT_PLEOMORPHIC               3566 non-null   int64
#  25  CT_PUNCTATE                  3566 non-null   int64
#  26  CT_ROUND_AND_REGULAR         3566 non-null   int64
#  27  CT_SKIN                      3566 non-null   int64
#  28  CT_VASCULAR                  3566 non-null   int64
#  29  CD_CLUSTERED                 3566 non-null   int64
#  30  CD_LINEAR                    3566 non-null   int64
#  31  CD_REGIONAL                  3566 non-null   int64
#  32  CD_DIFFUSELY_SCATTERED       3566 non-null   int64
#  33  CD_SEGMENTAL                 3566 non-null   int64
#  34  MS_IRREGULAR                 3566 non-null   int64
#  35  MS_ARCHITECTURAL_DISTORTION  3566 non-null   int64
#  36  MS_OVAL                      3566 non-null   int64
#  37  MS_LYMPH_NODE                3566 non-null   int64
#  38  MS_LOBULATED                 3566 non-null   int64
#  39  MS_FOCAL_ASYMMETRIC_DENSITY  3566 non-null   int64
#  40  MS_ROUND                     3566 non-null   int64
#  41  MS_ASYMMETRIC_BREAST_TISSUE  3566 non-null   int64
#  42  MM_SPICULATED                3566 non-null   int64
#  43  MM_ILL_DEFINED               3566 non-null   int64
#  44  MM_CIRCUMSCRIBED             3566 non-null   int64
#  45  MM_OBSCURED                  3566 non-null   int64
#  46  MM_MICROLOBULATED            3566 non-null   int64
# dtypes: bool(1), int64(35), object(11)
# memory usage: 1.3+ MB
#      patient_id  breast_density left_or_right_breast image_view  \
# 2815    P_01356               2                 LEFT         CC
# 2435    P_00802               2                 LEFT        MLO
# 3201    P_00116               2                RIGHT         CC
# 1468    P_02195               4                RIGHT        MLO
# 506     P_00635               3                 LEFT        MLO
# 1602    P_00344               4                 LEFT         CC
# 3296    P_00481               2                RIGHT         CC
# 119     P_00121               2                 LEFT        MLO
# 811     P_01040               3                RIGHT        MLO
# 259     P_00380               2                RIGHT        MLO
#
#       abnormality_id abnormality_type              calc_type  \
# 2815               1             mass         NOT APPLICABLE
# 2435               2             mass         NOT APPLICABLE
# 3201               1             mass         NOT APPLICABLE
# 1468               1    calcification            PLEOMORPHIC
# 506                1    calcification               PUNCTATE
# 1602               1    calcification            PLEOMORPHIC
# 3296               1             mass         NOT APPLICABLE
# 119                1    calcification   PUNCTATE-PLEOMORPHIC
# 811                1    calcification            PLEOMORPHIC
# 259                1    calcification  FINE_LINEAR_BRANCHING
#
#      calc_distribution  assessment                pathology  subtlety fileset  \
# 2815    NOT APPLICABLE           5                MALIGNANT         5   train
# 2435    NOT APPLICABLE           5                MALIGNANT         5   train
# 3201    NOT APPLICABLE           5                MALIGNANT         5    test
# 1468         CLUSTERED           0                MALIGNANT         4   train
# 506          SEGMENTAL           2  BENIGN_WITHOUT_CALLBACK         4   train
# 1602         CLUSTERED           4                   BENIGN         5    test
# 3296    NOT APPLICABLE           4                MALIGNANT         4    test
# 119          CLUSTERED           4                MALIGNANT         3   train
# 811          CLUSTERED           4                   BENIGN         2   train
# 259          CLUSTERED           4                   BENIGN         5   train
#
#                               mass_shape    mass_margins  \
# 2815                           IRREGULAR      SPICULATED
# 2435                           IRREGULAR      SPICULATED
# 3201  IRREGULAR-ARCHITECTURAL_DISTORTION      SPICULATED
# 1468                      NOT APPLICABLE  NOT APPLICABLE
# 506                       NOT APPLICABLE  NOT APPLICABLE
# 1602                      NOT APPLICABLE  NOT APPLICABLE
# 3296                               ROUND      SPICULATED
# 119                       NOT APPLICABLE  NOT APPLICABLE
# 811                       NOT APPLICABLE  NOT APPLICABLE
# 259                       NOT APPLICABLE  NOT APPLICABLE
#
#                                 case_id  cancer  CT_AMORPHOUS  CT_COARSE  \
# 2815             P_01356_LEFT_mass_CC_1    True             0          0
# 2435            P_00802_LEFT_mass_MLO_2    True             0          0
# 3201            P_00116_RIGHT_mass_CC_1    True             0          0
# 1468  P_02195_RIGHT_calcification_MLO_1    True             0          0
# 506    P_00635_LEFT_calcification_MLO_1   False             0          0
# 1602    P_00344_LEFT_calcification_CC_1   False             0          0
# 3296            P_00481_RIGHT_mass_CC_1    True             0          0
# 119    P_00121_LEFT_calcification_MLO_1    True             0          0
# 811   P_01040_RIGHT_calcification_MLO_1   False             0          0
# 259   P_00380_RIGHT_calcification_MLO_1   False             0          0
#
#       CT_DYSTROPHIC  CT_EGGSHELL  CT_FINE_LINEAR_BRANCHING  CT_LARGE_RODLIKE  \
# 2815              0            0                         0                 0
# 2435              0            0                         0                 0
# 3201              0            0                         0                 0
# 1468              0            0                         0                 0
# 506               0            0                         0                 0
# 1602              0            0                         0                 0
# 3296              0            0                         0                 0
# 119               0            0                         0                 0
# 811               0            0                         0                 0
# 259               0            0                         1                 0
#
#       CT_LUCENT_CENTERED  CT_MILK_OF_CALCIUM  CT_PLEOMORPHIC  CT_PUNCTATE  \
# 2815                   0                   0               0            0
# 2435                   0                   0               0            0
# 3201                   0                   0               0            0
# 1468                   0                   0               1            0
# 506                    0                   0               0            1
# 1602                   0                   0               1            0
# 3296                   0                   0               0            0
# 119                    0                   0               1            1
# 811                    0                   0               1            0
# 259                    0                   0               0            0
#
#       CT_ROUND_AND_REGULAR  CT_SKIN  CT_VASCULAR  CD_CLUSTERED  CD_LINEAR  \
# 2815                     0        0            0             0          0
# 2435                     0        0            0             0          0
# 3201                     0        0            0             0          0
# 1468                     0        0            0             1          0
# 506                      0        0            0             0          0
# 1602                     0        0            0             1          0
# 3296                     0        0            0             0          0
# 119                      0        0            0             1          0
# 811                      0        0            0             1          0
# 259                      0        0            0             1          0
#
#       CD_REGIONAL  CD_DIFFUSELY_SCATTERED  CD_SEGMENTAL  MS_IRREGULAR  \
# 2815            0                       0             0             1
# 2435            0                       0             0             1
# 3201            0                       0             0             1
# 1468            0                       0             0             0
# 506             0                       0             1             0
# 1602            0                       0             0             0
# 3296            0                       0             0             0
# 119             0                       0             0             0
# 811             0                       0             0             0
# 259             0                       0             0             0
#
#       MS_ARCHITECTURAL_DISTORTION  MS_OVAL  MS_LYMPH_NODE  MS_LOBULATED  \
# 2815                            0        0              0             0
# 2435                            0        0              0             0
# 3201                            1        0              0             0
# 1468                            0        0              0             0
# 506                             0        0              0             0
# 1602                            0        0              0             0
# 3296                            0        0              0             0
# 119                             0        0              0             0
# 811                             0        0              0             0
# 259                             0        0              0             0
#
#       MS_FOCAL_ASYMMETRIC_DENSITY  MS_ROUND  MS_ASYMMETRIC_BREAST_TISSUE  \
# 2815                            0         0                            0
# 2435                            0         0                            0
# 3201                            0         0                            0
# 1468                            0         0                            0
# 506                             0         0                            0
# 1602                            0         0                            0
# 3296                            0         1                            0
# 119                             0         0                            0
# 811                             0         0                            0
# 259                             0         0                            0
#
#       MM_SPICULATED  MM_ILL_DEFINED  MM_CIRCUMSCRIBED  MM_OBSCURED  \
# 2815              1               0                 0            0
# 2435              1               0                 0            0
# 3201              1               0                 0            0
# 1468              0               0                 0            0
# 506               0               0                 0            0
# 1602              0               0                 0            0
# 3296              1               0                 0            0
# 119               0               0                 0            0
# 811               0               0                 0            0
# 259               0               0                 0            0
#
#       MM_MICROLOBULATED
# 2815                  0
# 2435                  0
# 3201                  0
# 1468                  0
# 506                   0
# 1602                  0
# 3296                  0
# 119                   0
# 811                   0
# 259                   0
