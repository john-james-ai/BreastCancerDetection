# %% [markdown]
# # Weights and Biases Lab

# %%
import os
import wandb
from dotenv import load_dotenv
from bcd.model.project import Project
load_dotenv()
# Out:
# True

# %%
entity = os.getenv("WANDB_ENTITY")
project = "BCD_V1_CBIS-DDSM-10_20240208-0248"
run_id = "comic-bush-1"

# %%
api = wandb.Api()
runs = api.runs(f"{entity}/{project}")
for run in runs:
    print(run.name)
# Out:
# tough-brook-6
# spring-shape-5
# dutiful-waterfall-4
# skilled-snowball-3
# ethereal-durian-2
# comic-bush-1

# %%
history = runs[0].history()
loss =  history[["_step", "epoch/loss", "epoch/val_loss"]]
loss.columns = ["epoch", "train", "validation"]
loss = loss.melt(id_vars=["epoch"], value_vars=["train", "validation"], var_name="dataset", value_name="loss")
loss['epoch'] += 1
loss
# Out:
#     epoch  train  validation
# 0       0   0.71        0.68
# 1       1   0.71        0.68
# 2       2   0.71        0.68
# 3       3   0.71        0.68
# 4       4   0.71        0.68
# 5       5   0.69        0.68
# 6       6   0.69        0.68
# 7       7   0.69        0.68
# 8       8   0.69        0.68
# 9       9   0.69        0.68
# 10     10   0.71        0.68
# 11     11   0.71        0.68
# 12     12   0.71        0.68
# 13     13   0.71        0.68
# 14     14   0.71        0.68
# 15     15   0.69        0.68
# 16     16   0.69        0.68
# 17     17   0.69        0.68
# 18     18   0.69        0.68
# 19     19   0.69        0.68
# 20     20   0.69        0.68
# 21     21   0.69        0.68
# 22     22   0.69        0.68
# 23     23   0.69        0.68
# 24     24   0.69        0.68
# 25     25   0.68        0.68
# 26     26   0.68        0.68
# 27     27   0.68        0.68
# 28     28   0.68        0.68
# 29     29   0.68        0.68
# 30     30   0.69        0.68
# 31     31   0.69        0.68
# 32     32   0.69        0.68
# 33     33   0.69        0.68
# 34     34   0.69        0.68
# 35     35   0.71        0.68
# 36     36   0.71        0.68
# 37     37   0.71        0.68
# 38     38   0.71        0.68
# 39     39   0.71        0.68
# 40     40   0.72        0.68
# 41     41   0.72        0.68
# 42     42   0.72        0.68
# 43     43   0.72        0.68
# 44     44   0.72        0.68
# 45     45   0.71        0.68
# 46     46   0.71        0.68
# 47     47   0.71        0.68
# 48     48   0.71        0.68
# 49     49   0.71        0.68
# 50     50   0.70        0.68
# 51     51   0.70        0.68
# 52     52   0.70        0.68
# 53     53   0.70        0.68
# 54     54   0.70        0.68
#      epoch     dataset  loss
# 0        1       train  0.71
# 1        2       train  0.71
# 2        3       train  0.71
# 3        4       train  0.71
# 4        5       train  0.71
# ..     ...         ...   ...
# 105     51  validation  0.68
# 106     52  validation  0.68
# 107     53  validation  0.68
# 108     54  validation  0.68
# 109     55  validation  0.68
#
# [110 rows x 3 columns]

# %%
p = Project(name="BCD_V1_CBIS-DDSM-10_20240208-0248")
p.plot_learning_curve(name="DenseNet201")
# Out:
# Run DenseNet201 not found.
# NoneType: None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 p = Project(name="BCD_V1_CBIS-DDSM-10_20240208-0248")
# ----> 2 p.plot_learning_curve(name="DenseNet201")
#
# File ~/projects/bcd/bcd/model/project.py:62, in Project.plot_learning_curve(self, name, ax)
#      59 if ax is None:
#      60     _, ax = plt.subplots(figsize=(12, 4))
# ---> 62 run = self._get_run(name=name)
#      64 history = run.history()
#      65 loss = history[["_step", "epoch/loss", "epoch/val_loss"]]
#
# File ~/projects/bcd/bcd/model/project.py:86, in Project._get_run(self, name)
#      84 msg = f"Run {name} not found."
#      85 self._logger.exception(msg)
# ---> 86 raise FileNotFoundError(msg)
#
# FileNotFoundError: Run DenseNet201 not found.
