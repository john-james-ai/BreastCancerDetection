# %% [markdown]
# # Denoiser Analyzer

# %%
from bcd.preprocess.image.analysis.noise import MeanFilterAnalyzer, GaussianFilterAnalyzer, MedianFilterAnalyzer

# %%
analyzer = MedianFilterAnalyzer()
analyzer.add_speckle_noise()
_ = analyzer.compare()
