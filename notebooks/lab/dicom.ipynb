# %% [markdown]
# # DICOM Lab

# %%
import pandas as pd
from bcd.data.dataset.dicom import DicomDataset
pd.options.display.max_columns = 999

# %%
FP = "data/clean/dicom_case.csv"

# %%
ds = DicomDataset(filepath=FP)
condition = lambda df: ((df["abnormality_type"] == "mass") & (df['cancer'] == False))
ds.plot_images(condition, n=8, rows=4, cols=2)
# Out:
# ...
# 100%|██████████| 8/8 [00:01<00:00,  5.88it/s]
