# %% [markdown]
# # EDA Lab

# %%
import sys
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from scipy import stats
from IPython.display import display_html, HTML
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

from bcd.data.dataset.case import CaseExplorer, CALCIFICATION_DATA, MASS_DATA
from bcd.data.dataset.dicom import DicomExplorer

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
sns.set_style('whitegrid')
sns.set_palette("Blues_r")

# %%
CASE_FP = "data/clean/cases_enc.csv"
DICOM_FP = "data/meta/1_staged/dicom.csv"

# %%
cases = CaseExplorer(filepath=CASE_FP)

# %%
_ = cases.compare_morphology(m1='calc_type', m2='calc_distribution', figsize=(12,12), orient='v')
