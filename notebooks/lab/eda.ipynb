# %% [markdown]
# # EDA Lab

# %%
import sys
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from scipy import stats
from IPython.display import display_html, HTML
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

from bcd.data.dataset.case import CaseDataset, CALCIFICATION_DATA, MASS_DATA
from bcd.data.dataset.dicom import DicomDataset

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
sns.set_style('whitegrid')
sns.set_palette("Blues_r")

# %%
CASE_FP = "data/clean/cases_enc.csv"
DICOM_FP = "data/staged/dicom.csv"

# %%
cases = CaseDataset(filepath=CASE_FP)

# %%
_ = cases.compare_morphology(m1='calc_type', m2='calc_distribution', figsize=(12,12), orient='v')
# Out:
#                                            proportion
# calc_type             calc_distribution
# AMORPHOUS             CLUSTERED                  0.63
#                       DIFFUSELY_SCATTERED        0.01
#                       LINEAR                     0.06
#                       REGIONAL                   0.14
#                       SEGMENTAL                  0.16
# COARSE                CLUSTERED                  0.07
#                       REGIONAL                   0.02
#                       SEGMENTAL                  0.90
# DYSTROPHIC            CLUSTERED                  0.82
#                       DIFFUSELY_SCATTERED        0.09
#                       SEGMENTAL                  0.09
# EGGSHELL              SEGMENTAL                  1.00
# FINE_LINEAR_BRANCHING CLUSTERED                  0.45
#                       LINEAR                     0.44
#                       REGIONAL                   0.06
#                       SEGMENTAL                  0.22
# LARGE_RODLIKE         REGIONAL                   0.73
#                       SEGMENTAL                  0.27
# LUCENT_CENTERED       DIFFUSELY_SCATTERED        0.11
#                       LINEAR                     0.00
#                       REGIONAL                   0.02
#                       SEGMENTAL                  0.87
# MILK_OF_CALCIUM       CLUSTERED                  1.00
# PLEOMORPHIC           CLUSTERED                  0.75
#                       DIFFUSELY_SCATTERED        0.01
#                       LINEAR                     0.08
#                       REGIONAL                   0.05
#                       SEGMENTAL                  0.15
# PUNCTATE              CLUSTERED                  0.50
#                       DIFFUSELY_SCATTERED        0.12
#                       LINEAR                     0.02
#                       REGIONAL                   0.09
#                       SEGMENTAL                  0.28
# ROUND_AND_REGULAR     CLUSTERED                  0.12
#                       DIFFUSELY_SCATTERED        0.15
#                       REGIONAL                   0.11
#                       SEGMENTAL                  0.62
# SKIN                  REGIONAL                   0.15
#                       SEGMENTAL                  0.85
# VASCULAR              LINEAR                     0.07
#                       REGIONAL                   0.02
#                       SEGMENTAL                  0.92
