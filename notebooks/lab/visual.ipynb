# %% [markdown]
# # Visualization Lab

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from bcd.data.dataset.case import CaseExplorer

# %%
FP = "data/clean/cases.csv"

# %% [markdown]
# ## Prepare Data

# %%
df = pd.read_csv(FP)
ds = CaseExplorer(filepath=FP)
ds.plot_target_associations()

# %%
fig, ax = plt.subplots(figsize=(12,12))
ds.plot_feature_associations(ax=ax)
