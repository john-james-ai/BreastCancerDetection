# %%
import pydicom

# %%
rawcc = "data/image/0_raw/CBIS-DDSM/Calc-Test_P_00100_RIGHT_CC/08-29-2017-DDSM-99985/1.000000-full mammogram images-10348/1-1.dcm"
rawcc2 = "data/image/0_raw/CBIS-DDSM/Calc-Test_P_00100_RIGHT_CC_1/08-29-2017-DDSM-29651/1.000000-ROI mask images-97035/1-2.dcm"
suspect = "data/image/0_raw/CBIS-DDSM/Mass-Training_P_01382_LEFT_MLO/07-20-2016-DDSM-93921/1.000000-full mammogram images-05891/1-1.dcm"
roi1 = "data/image/0_raw/CBIS-DDSM/Calc-Training_P_01128_RIGHT_CC_1/09-06-2017-DDSM-65566/1.000000-ROI mask images-91132/1-1.dcm"
roi2 = "data/image/0_raw/CBIS-DDSM/Calc-Training_P_01128_RIGHT_CC_1/09-06-2017-DDSM-65566/1.000000-ROI mask images-91132/1-2.dcm"

# %%
ds1 = pydicom.dcmread(rawcc)
ds1.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds1 = pydicom.dcmread(rawcc)
#       2 ds1.shape
#
# File ~/anaconda3/envs/bcd/lib/python3.10/site-packages/pydicom/filereader.py:1002, in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1000     caller_owns_file = False
#    1001     logger.debug("Reading file '{0}'".format(fp))
# -> 1002     fp = open(fp, 'rb')
#    1003 elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#    1004     raise TypeError("dcmread: Expected a file path or a file-like, "
#    1005                     "but got " + type(fp).__name__)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/image/0_raw//Calc-Test_P_00100_RIGHT_CC/08-29-2017-DDSM-99985/1.000000-full mammogram images-10348/1-1.dcm'

# %%
ds1 = pydicom.dcmread(rawcc)
ds2 = pydicom.dcmread(rawcc2)
ds3 = pydicom.dcmread(roi1)
ds4 = pydicom.dcmread(roi2)
ds1
ds2
ds3
ds4
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.994853711178750420292760930232102965
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.994853711178750420292760930232102965
# (0008, 0020) Study Date                          DA: ''
# ...

# %%
pydicom.dcmread(rawcc)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 192
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.994853711178750420292760930232102965
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.994853711178750420292760930232102965
# (0008, 0020) Study Date                          DA: ''
# ...
