# %% [markdown]
# # Dask Lab

# %%
import os
import pandas as pd
from glob import glob
from bcd.data_prep.dicom import DicomPrep
from bcd.dal.file import IOService
pd.set_option('display.max_colwidth', None)

# %%
series = "data/meta/0_raw/metadata.csv"
dicom = "data/meta/1_interim/dicom.csv"

# %%
p = DicomPrep(filepath=series, dicom_filepath=dicom, force=True)
dicom = p.prep()

# %%
dicom.head()
# Out:
#   patient_id                    subject_id abnormality_type laterality  \
# 0    P_01004  Calc-Test_P_01004_LEFT_MLO_1             calc       LEFT
# 1    P_01004  Calc-Test_P_01004_LEFT_MLO_1             calc       LEFT
# 2    P_00038  Calc-Test_P_00038_LEFT_MLO_1             calc       LEFT
# 3    P_00038  Calc-Test_P_00038_LEFT_MLO_1             calc       LEFT
# 4    P_00041  Calc-Test_P_00041_LEFT_MLO_2             calc       LEFT
#
#   image_view fileset series_description photometric_interpretation  bit_depth  \
# 0        MLO    test    ROI mask images                MONOCHROME2         16
# 1        MLO    test    ROI mask images                MONOCHROME2         16
# 2        MLO    test    ROI mask images                MONOCHROME2         16
# 3        MLO    test    ROI mask images                MONOCHROME2         16
# 4        MLO    test    ROI mask images                MONOCHROME2         16
#
#    rows  cols  aspect_ratio    size  file_size  min_pixel_value  \
# 0   777   593          0.76  460761  900.98 KB            31362
# 1   777   593          0.76  460761  900.98 KB            31362
# 2   265   249          0.94   65985  129.94 KB             6073
# 3   265   249          0.94   65985  129.94 KB             6073
# 4   145   145          1.00   21025   42.12 KB            23229
#
#    max_pixel_value  mean_pixel_value  std_pixel_value  \
# 0            65535         45,308.41         5,145.27
# 1            65535         45,308.41         5,145.27
# 2            65535         35,246.98        12,114.55
# 3            65535         35,246.98        12,114.55
# 4            65535         31,677.93         9,333.01
#
#                                                                                                                filepath  \
# 0  data/image/0_raw/CBIS-DDSM/Calc-Test_P_01004_LEFT_MLO_1/08-29-2017-DDSM-89570/1.000000-ROI mask images-17726/1-1.dcm
# 1  data/image/0_raw/CBIS-DDSM/Calc-Test_P_01004_LEFT_MLO_1/08-29-2017-DDSM-89570/1.000000-ROI mask images-17726/1-1.dcm
# 2  data/image/0_raw/CBIS-DDSM/Calc-Test_P_00038_LEFT_MLO_1/08-29-2017-DDSM-11739/1.000000-ROI mask images-88680/1-1.dcm
# 3  data/image/0_raw/CBIS-DDSM/Calc-Test_P_00038_LEFT_MLO_1/08-29-2017-DDSM-11739/1.000000-ROI mask images-88680/1-1.dcm
# 4  data/image/0_raw/CBIS-DDSM/Calc-Test_P_00041_LEFT_MLO_2/08-29-2017-DDSM-87987/1.000000-ROI mask images-37601/1-1.dcm
#
#                        mmg_id
# 0  Calc-Test_P_01004_LEFT_MLO
# 1  Calc-Test_P_01004_LEFT_MLO
# 2  Calc-Test_P_00038_LEFT_MLO
# 3  Calc-Test_P_00038_LEFT_MLO
# 4  Calc-Test_P_00041_LEFT_MLO
