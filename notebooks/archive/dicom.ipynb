# %% [markdown]
# # DICOM Lab

# %%
import pandas as pd
from bcd.explore.meta.dicom import DicomExplorer
pd.options.display.max_columns = 999

# %%
FP = "data/meta/2_clean/dicom.csv"

# %%
ds = DicomExplorer(filepath=FP)
condition = lambda df: ((df["abnormality_type"] == "mass") & (df['cancer'] == False))
ds.plot_images(condition, n=8, nrows=4, ncols=2)
