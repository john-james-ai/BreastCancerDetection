# %%
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../../..")))

import pandas as pd
from IPython.display import HTML, display_html
import numpy as np

from bcd.analyze.dqa.cbis import CBISDQA
from bcd.data.dataset import CBISDataset

pd.set_option('display.max_colwidth', 200)

# %%
filepath = "data/meta/2_staged/cbis.csv"
cbis = CBISDataset(filepath=filepath)
cbis.dqa = CBISDQA

# %%
dqc = cbis.dqa.analyze_completeness()
print(dqc.summary, end=" ")
# Out:
#                           Completeness
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                 Complete Records | 3043
#              Record Completeness | 0.853
#                      Data Values | 96336
#             Complete Data Values | 95809
#          Data Value Completeness | 0.995

# %%
dqc.detail
# Out:
#                       N  Complete  Missing  Completeness
# patient_id         3568      3568        0          1.00
# breast_density     3568      3568        0          1.00
# laterality         3568      3568        0          1.00
# image_view         3568      3568        0          1.00
# abnormality_id     3568      3568        0          1.00
# abnormality_type   3568      3568        0          1.00
# calc_type          3568      3544       24          0.99
# calc_distribution  3568      3129      439          0.88
# assessment         3568      3568        0          1.00
# pathology          3568      3568        0          1.00
# subtlety           3568      3568        0          1.00
# fileset            3568      3568        0          1.00
# mass_shape         3568      3564        4          1.00
# mass_margins       3568      3508       60          0.98
# mmg_id             3568      3568        0          1.00
# cancer             3568      3568        0          1.00
# bit_depth          3568      3568        0          1.00
# rows               3568      3568        0          1.00
# cols               3568      3568        0          1.00
# aspect_ratio       3568      3568        0          1.00
# size               3568      3568        0          1.00
# file_size          3568      3568        0          1.00
# min_pixel_value    3568      3568        0          1.00
# max_pixel_value    3568      3568        0          1.00
# mean_pixel_value   3568      3568        0          1.00
# std_pixel_value    3568      3568        0          1.00
# filepath           3568      3568        0          1.00

# %%
cbis.dqa.get_incomplete_data(subset='calc_distribution')['pathology'].value_counts().to_frame()
# Out:
#                          count
# pathology
# BENIGN_WITHOUT_CALLBACK    434
# BENIGN                       5

# %%
dqu = cbis.dqa.analyze_uniqueness()
print(dqu.summary)
# Out:
#                            Uniqueness
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                   Unique Records | 3568
#                Record Uniqueness | 1.0
#                      Data Values | 96336
#               Unique Data Values | 23101
#            Data Value Uniqueness | 0.24

# %%
dqv = cbis.dqa.analyze_validity()
print(dqv.summary)
# Out:
#                             Validity
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                    Valid Records | 3009
#                  Record Validity | 0.843
#                      Data Values | 96336
#                Valid Data Values | 95608
#              Data Value Validity | 0.992

# %%
dqv.detail
# Out:
#                       N  Valid  Invalid  Validity
# mmg_id             3568   3568        0      1.00
# patient_id         3568   3568        0      1.00
# breast_density     3568   3566        2      1.00
# laterality         3568   3568        0      1.00
# image_view         3568   3568        0      1.00
# abnormality_id     3568   3568        0      1.00
# abnormality_type   3568   3568        0      1.00
# calc_type          3568   3347      221      0.94
# calc_distribution  3568   3129      439      0.88
# mass_shape         3568   3564        4      1.00
# mass_margins       3568   3508       60      0.98
# assessment         3568   3568        0      1.00
# pathology          3568   3568        0      1.00
# subtlety           3568   3566        2      1.00
# fileset            3568   3568        0      1.00
# cancer             3568   3568        0      1.00
# bit_depth          3568   3568        0      1.00
# rows               3568   3568        0      1.00
# cols               3568   3568        0      1.00
# aspect_ratio       3568   3568        0      1.00
# size               3568   3568        0      1.00
# file_size          3568   3568        0      1.00
# min_pixel_value    3568   3568        0      1.00
# max_pixel_value    3568   3568        0      1.00
# mean_pixel_value   3568   3568        0      1.00
# std_pixel_value    3568   3568        0      1.00
# filepath           3568   3568        0      1.00

# %%
cbis.dqa.get_invalid_data(subset='calc_type')['calc_type'].unique()
# Out:
# array([nan, 'ROUND_AND_REGULAR-LUCENT_CENTER-DYSTROPHIC',
#        'PUNCTATE-LUCENT_CENTER',
#        'VASCULAR-COARSE-LUCENT_CENTER-ROUND_AND_REGULAR-PUNCTATE',
#        'LUCENT_CENTER', 'ROUND_AND_REGULAR-LUCENT_CENTER',
#        'LUCENT_CENTER-PUNCTATE', 'PLEOMORPHIC-PLEOMORPHIC',
#        'COARSE-ROUND_AND_REGULAR-LUCENT_CENTER',
#        'ROUND_AND_REGULAR-LUCENT_CENTER-PUNCTATE', 'COARSE-LUCENT_CENTER'],
#       dtype=object)

# %%
cbis.dqa.get_invalid_data(subset='breast_density')
# Out:
#      patient_id  breast_density laterality image_view  abnormality_id  \
# 1817    P_01743               0      RIGHT         CC               1
# 1818    P_01743               0      RIGHT        MLO               1
#
#      abnormality_type    calc_type    calc_distribution  assessment  \
# 1817    calcification  PLEOMORPHIC  DIFFUSELY_SCATTERED           5
# 1818    calcification  PLEOMORPHIC  DIFFUSELY_SCATTERED           5
#
#       pathology  ...  rows  cols aspect_ratio      size file_size  \
# 1817  MALIGNANT  ...  4576  1831         0.40   8378656  16758290
# 1818  MALIGNANT  ...  5176  2716         0.52  14058016  28117014
#
#       min_pixel_value  max_pixel_value  mean_pixel_value  std_pixel_value  \
# 1817                0            65535         10,701.68        19,437.31
# 1818                0            65535         14,108.36        20,763.14
#
#                                                                                                                        filepath
# 1817   data/image/0_raw/CBIS-DDSM/Calc-Test_P_01743_RIGHT_CC/08-29-2017-DDSM-78699/1.000000-full mammogram images-62009/1-1.dcm
# 1818  data/image/0_raw/CBIS-DDSM/Calc-Test_P_01743_RIGHT_MLO/08-29-2017-DDSM-15483/1.000000-full mammogram images-98404/1-1.dcm
#
# [2 rows x 27 columns]

# %%
df = cbis.dqa.get_complete_data()
df_similar_type = df.loc[(df['calc_type'] == 'PLEOMORPHIC') & (df['cancer'] == True)]
df_similar_dist = df.loc[(df['calc_distribution'] == 'DIFFUSELY_SCATTERED') & (df['cancer'] == True)]

# %%
df_similar_type['breast_density'].value_counts().to_frame()
# Out:
#                 count
# breast_density
# 3                 158
# 2                 123
# 4                 121
# 1                  23
# 0                   2

# %%
df_similar_dist['breast_density'].value_counts().to_frame()
# Out:
#                 count
# breast_density
# 2                   2
# 0                   2
# 3                   1

# %%
cbis.dqa.get_invalid_data(subset='subtlety')
# Out:
#      patient_id  breast_density laterality image_view  abnormality_id  \
# 2364    P_00710               2      RIGHT         CC               1
# 2365    P_00710               2      RIGHT        MLO               1
#
#      abnormality_type       calc_type calc_distribution  assessment pathology  \
# 2364             mass  NOT APPLICABLE    NOT APPLICABLE           0    BENIGN
# 2365             mass  NOT APPLICABLE    NOT APPLICABLE           0    BENIGN
#
#       ...  rows  cols aspect_ratio      size file_size  min_pixel_value  \
# 2364  ...  4728  3112         0.66  14713536  29428168                0
# 2365  ...  4688  3120         0.67  14626560  29254222                0
#
#       max_pixel_value  mean_pixel_value  std_pixel_value  \
# 2364            65535          6,370.67        12,047.63
# 2365            65535         10,743.82        15,182.58
#
#                                                                                                                            filepath
# 2364   data/image/0_raw/CBIS-DDSM/Mass-Training_P_00710_RIGHT_CC/07-20-2016-DDSM-01521/1.000000-full mammogram images-11222/1-1.dcm
# 2365  data/image/0_raw/CBIS-DDSM/Mass-Training_P_00710_RIGHT_MLO/07-20-2016-DDSM-11749/1.000000-full mammogram images-15311/1-1.dcm
#
# [2 rows x 27 columns]
