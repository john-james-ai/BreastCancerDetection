# %%
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../../..")))

import pandas as pd
import numpy as np

from bcd.data_prep.cbis import CBISImputer
from bcd.data.dataset import CBISDataset

pd.options.display.max_rows = 999

# %%
FP_STAGED = "data/meta/2_staged/cbis.csv"
FP_CLEAN = "data/meta/3_clean/cbis.csv"

# %%
df = pd.read_csv(FP_STAGED)
df_orig = df.copy()

# %%
# Set invalid values for breast_density to NA
df['breast_density'] = df['breast_density'].replace(0, np.NAN)

# %%
# Set case and mass data to NOT APPLICABLE where appropriate.
df['subtlety'] = df['subtlety'].replace(0, np.NAN)

# %%
df.loc[df['calc_type'] == 'LUCENT_CENTER', 'calc_type'] = 'LUCENT_CENTERED'
df.loc[df['calc_type'] == 'ROUND_AND_REGULAR-LUCENT_CENTER-DYSTROPHIC', 'calc_type'] = 'ROUND_AND_REGULAR-LUCENT_CENTERED-DYSTROPHIC'
df.loc[df['calc_type'] == 'PUNCTATE-LUCENT_CENTER', 'calc_type'] = 'PUNCTATE-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'VASCULAR-COARSE-LUCENT_CENTER-ROUND_AND_REGULAR-PUNCTATE', 'calc_type'] = 'VASCULAR-COARSE-LUCENT_CENTERED-ROUND_AND_REGULAR-PUNCTATE'
df.loc[df['calc_type'] == 'ROUND_AND_REGULAR-LUCENT_CENTER', 'calc_type'] = 'ROUND_AND_REGULAR-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'LUCENT_CENTER-PUNCTATE', 'calc_type'] = 'LUCENT_CENTERED-PUNCTATE'
df.loc[df['calc_type'] == 'COARSE-ROUND_AND_REGULAR-LUCENT_CENTER', 'calc_type'] = 'COARSE-ROUND_AND_REGULAR-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'ROUND_AND_REGULAR-LUCENT_CENTER-PUNCTATE', 'calc_type'] = 'ROUND_AND_REGULAR-LUCENT_CENTERED-PUNCTATE'
df.loc[df['calc_type'] == 'COARSE-LUCENT_CENTER', 'calc_type'] = 'COARSE-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'PLEOMORPHIC-PLEOMORPHIC', 'calc_type'] = 'PLEOMORPHIC'

# %%
# Grab rows with missing data
null_mask = df.isnull().any(axis=1)
df_missing = df[null_mask]
msg = f"There are {df_missing.shape[0]} rows (approximately {round(df_missing.shape[0] / df_orig.shape[0] * 100,1)}% of the dataset) with missing data in the dataset."
print(msg)
# Out:
# There are 527 rows (approximately 14.8% of the dataset) with missing data in the dataset.

# %%
imp = CBISImputer(random_state=5)
imp.fit(df=df)
df_clean = imp.transform(df=df)

# %%
os.makedirs(os.path.dirname(FP_CLEAN), exist_ok=True)
df_clean.to_csv(FP_CLEAN, index=False)

# %%
sample_cases = df_missing['mmg_id'].sample(5)
df_missing.loc[df_missing['mmg_id'].isin(sample_cases)]
df_clean.loc[df_clean['mmg_id'].isin(sample_cases)]
# Out:
#      patient_id  breast_density laterality image_view  abnormality_id  \
# 105     P_00112            3.00      RIGHT         CC               1
# 106     P_00112            3.00      RIGHT         CC               2
# 107     P_00112            3.00      RIGHT         CC               3
# 108     P_00112            3.00      RIGHT         CC               4
# 109     P_00112            3.00      RIGHT         CC               5
# 110     P_00112            3.00      RIGHT         CC               6
# 313     P_00452            2.00      RIGHT         CC               1
# 314     P_00452            2.00      RIGHT         CC               2
# 665     P_00840            4.00      RIGHT         CC               1
# 1267    P_01628            3.00      RIGHT         CC               1
# 1268    P_01628            3.00      RIGHT         CC               2
# 1818    P_01743             NaN      RIGHT        MLO               1
#
#      abnormality_type                   calc_type    calc_distribution  \
# 105     calcification  ROUND_AND_REGULAR-EGGSHELL                  NaN
# 106     calcification  ROUND_AND_REGULAR-EGGSHELL                  NaN
# 107     calcification  ROUND_AND_REGULAR-EGGSHELL                  NaN
# 108     calcification  ROUND_AND_REGULAR-EGGSHELL                  NaN
# 109     calcification  ROUND_AND_REGULAR-EGGSHELL                  NaN
# 110     calcification  ROUND_AND_REGULAR-EGGSHELL                  NaN
# 313     calcification                    VASCULAR                  NaN
# 314     calcification                    VASCULAR                  NaN
# 665     calcification             LUCENT_CENTERED                  NaN
# 1267    calcification             LUCENT_CENTERED                  NaN
# 1268    calcification             LUCENT_CENTERED                  NaN
# 1818    calcification                 PLEOMORPHIC  DIFFUSELY_SCATTERED
#
#       assessment                pathology  ...  rows  cols aspect_ratio  \
# 105            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         0.67
# 106            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         0.67
# 107            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         0.67
# 108            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         0.67
# 109            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         0.67
# 110            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         0.67
# 313            2  BENIGN_WITHOUT_CALLBACK  ...  4624  3096         0.67
# 314            2  BENIGN_WITHOUT_CALLBACK  ...  4624  3096         0.67
# 665            2  BENIGN_WITHOUT_CALLBACK  ...  4624  3064         0.66
# 1267           2  BENIGN_WITHOUT_CALLBACK  ...  5528  4112         0.74
# 1268           2  BENIGN_WITHOUT_CALLBACK  ...  5528  4112         0.74
# 1818           5                MALIGNANT  ...  5176  2716         0.52
#
#           size file_size  min_pixel_value  max_pixel_value  mean_pixel_value  \
# 105   14155776  28312648                0            65535          8,303.77
# 106   14155776  28312648                0            65535          8,303.77
# 107   14155776  28312648                0            65535          8,303.77
# 108   14155776  28312648                0            65535          8,303.77
# 109   14155776  28312648                0            65535          8,303.77
# 110   14155776  28312648                0            65535          8,303.77
# 313   14315904  28632904                0            65535         12,295.14
# 314   14315904  28632904                0            65535         12,295.14
# 665   14167936  28336968                0            65535          9,452.57
# 1267  22731136  45463368                0            65535          6,273.16
# 1268  22731136  45463368                0            65535          6,273.16
# 1818  14058016  28117014                0            65535         14,108.36
#
#       std_pixel_value                                           filepath
# 105         14,536.42  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 106         14,536.42  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 107         14,536.42  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 108         14,536.42  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 109         14,536.42  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 110         14,536.42  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 313         16,808.86  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 314         16,808.86  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 665         16,601.18  data/image/0_raw/CBIS-DDSM/Calc-Training_P_008...
# 1267        13,742.66  data/image/0_raw/CBIS-DDSM/Calc-Training_P_016...
# 1268        13,742.66  data/image/0_raw/CBIS-DDSM/Calc-Training_P_016...
# 1818        20,763.14  data/image/0_raw/CBIS-DDSM/Calc-Test_P_01743_R...
#
# [12 rows x 27 columns]
#      patient_id  breast_density laterality image_view  abnormality_id  \
# 105     P_00112            3.00      RIGHT         CC               1
# 106     P_00112            3.00      RIGHT         CC               2
# 107     P_00112            3.00      RIGHT         CC               3
# 108     P_00112            3.00      RIGHT         CC               4
# 109     P_00112            3.00      RIGHT         CC               5
# 110     P_00112            3.00      RIGHT         CC               6
# 313     P_00452            2.00      RIGHT         CC               1
# 314     P_00452            2.00      RIGHT         CC               2
# 665     P_00840            4.00      RIGHT         CC               1
# 1267    P_01628            3.00      RIGHT         CC               1
# 1268    P_01628            3.00      RIGHT         CC               2
# 1818    P_01743            3.00      RIGHT        MLO               1
#
#      abnormality_type                   calc_type    calc_distribution  \
# 105     calcification  ROUND_AND_REGULAR-EGGSHELL            SEGMENTAL
# 106     calcification  ROUND_AND_REGULAR-EGGSHELL            SEGMENTAL
# 107     calcification  ROUND_AND_REGULAR-EGGSHELL            SEGMENTAL
# 108     calcification  ROUND_AND_REGULAR-EGGSHELL            SEGMENTAL
# 109     calcification  ROUND_AND_REGULAR-EGGSHELL            SEGMENTAL
# 110     calcification  ROUND_AND_REGULAR-EGGSHELL            SEGMENTAL
# 313     calcification                    VASCULAR            SEGMENTAL
# 314     calcification                    VASCULAR            SEGMENTAL
# 665     calcification             LUCENT_CENTERED            SEGMENTAL
# 1267    calcification             LUCENT_CENTERED            SEGMENTAL
# 1268    calcification             LUCENT_CENTERED            SEGMENTAL
# 1818    calcification                 PLEOMORPHIC  DIFFUSELY_SCATTERED
#
#       assessment                pathology  ...  rows  cols aspect_ratio  \
# 105            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         1.00
# 106            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         1.00
# 107            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         1.00
# 108            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         1.00
# 109            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         1.00
# 110            2  BENIGN_WITHOUT_CALLBACK  ...  4608  3072         1.00
# 313            2  BENIGN_WITHOUT_CALLBACK  ...  4624  3096         1.00
# 314            2  BENIGN_WITHOUT_CALLBACK  ...  4624  3096         1.00
# 665            2  BENIGN_WITHOUT_CALLBACK  ...  4624  3064         1.00
# 1267           2  BENIGN_WITHOUT_CALLBACK  ...  5528  4112         1.00
# 1268           2  BENIGN_WITHOUT_CALLBACK  ...  5528  4112         1.00
# 1818           5                MALIGNANT  ...  5176  2716         1.00
#
#           size file_size  min_pixel_value  max_pixel_value  mean_pixel_value  \
# 105   14155776  28312648                0            65535          8,304.00
# 106   14155776  28312648                0            65535          8,304.00
# 107   14155776  28312648                0            65535          8,304.00
# 108   14155776  28312648                0            65535          8,304.00
# 109   14155776  28312648                0            65535          8,304.00
# 110   14155776  28312648                0            65535          8,304.00
# 313   14315904  28632904                0            65535         12,295.00
# 314   14315904  28632904                0            65535         12,295.00
# 665   14167936  28336968                0            65535          9,453.00
# 1267  22731136  45463368                0            65535          6,273.00
# 1268  22731136  45463368                0            65535          6,273.00
# 1818  14058016  28117014                0            65535         14,108.00
#
#       std_pixel_value                                           filepath
# 105         14,536.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 106         14,536.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 107         14,536.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 108         14,536.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 109         14,536.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 110         14,536.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_001...
# 313         16,809.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 314         16,809.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 665         16,601.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_008...
# 1267        13,743.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_016...
# 1268        13,743.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_016...
# 1818        20,763.00  data/image/0_raw/CBIS-DDSM/Calc-Test_P_01743_R...
#
# [12 rows x 27 columns]

# %%
ds = CBISDataset(filepath=FP_CLEAN)
dqcc = ds.dqa.analyze_completeness()
print(dqcc.summary)
# Out:
#                           Completeness
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                 Complete Records | 3568
#              Record Completeness | 1.0
#                      Data Values | 96336
#             Complete Data Values | 96336
#          Data Value Completeness | 1.0

# %%
dqcu = ds.dqa.analyze_uniqueness()
print(dqcu.summary)
# Out:
#                            Uniqueness
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                   Unique Records | 3568
#                Record Uniqueness | 1.0
#                      Data Values | 96336
#               Unique Data Values | 19864
#            Data Value Uniqueness | 0.206

# %%
dqcv = ds.dqa.analyze_validity()
print(dqcv.summary)
# Out:
#                             Validity
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                    Valid Records | 3568
#                  Record Validity | 1.0
#                      Data Values | 96336
#                Valid Data Values | 96336
#              Data Value Validity | 1.0
