# %% [markdown]
# # Data Cleaning
# The prior data quality analysis revealed several data anomalies requiring attention.
#
# 1. Cases with invalid values for subtlety and breast density.
# 2. Missing calcification type, calcification distribution, mass shape, and mass margins data.
# 3. Categories that have different spelling, but the same meaning.
#
# As such, the data cleaning tasks are detailed in {numref}`data_cleaning_tasks`:
#
# ```{table} Data Cleaning Tasks
# :name: data_cleaning_tasks
# | # | Task                                                                             |
# |---|----------------------------------------------------------------------------------|
# | 1 | Replace invalid values for breast density with NA for imputation.                |
# | 2 | Replace cases with invalid values for subtlety with NA for imputation            |
# | 3 | Replace calcification types 'LUCENT_CENTER' with 'LUCENT_CENTERED', and 'PLEOMORPHIC-PLEOMORPHIC', with 'PLEOMORPHIC' |
# | 4 | Impute missing values using Multiple Imputation by Chained Equations   (MICE)    |
# | 5 | Conduct random inspection of imputations.                                        |
# | 6 | Conduct final data quality analysis.                                        |
# ```
#
# Once the case dataset has been cleaned, the case data will be merged into the DICOM dataset.

# %%
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../../..")))

import pandas as pd
import numpy as np

from bcd.data_prep.clean import CBISImputer
from bcd.data.dataset import CBISDataset

pd.options.display.max_rows = 999

# %%
FP_STAGED = "data/meta/2_staged/cbis.csv"
FP_CLEAN = "data/meta/3_clean/cbis.csv"

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(FP_STAGED)
df_orig = df.copy()

# %% [markdown]
# ## Breast Density
# Replace invalid values for breast density with NA for downstream imputation.

# %%
# Set invalid values for breast_density to NA
df['breast_density'] = df['breast_density'].replace(0, np.NAN)

# %% [markdown]
# ## Subtlety
# Replace invalid values for subtlety with NA.

# %%
# Set case and mass data to NOT APPLICABLE where appropriate.
df['subtlety'] = df['subtlety'].replace(0, np.NAN)

# %% [markdown]
# ## Category Alignment
# Align categories that have the same meaning, but differ in spelling only.

# %%
df.loc[df['calc_type'] == 'LUCENT_CENTER', 'calc_type'] = 'LUCENT_CENTERED'
df.loc[df['calc_type'] == 'ROUND_AND_REGULAR-LUCENT_CENTER-DYSTROPHIC', 'calc_type'] = 'ROUND_AND_REGULAR-LUCENT_CENTERED-DYSTROPHIC'
df.loc[df['calc_type'] == 'PUNCTATE-LUCENT_CENTER', 'calc_type'] = 'PUNCTATE-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'VASCULAR-COARSE-LUCENT_CENTER-ROUND_AND_REGULAR-PUNCTATE', 'calc_type'] = 'VASCULAR-COARSE-LUCENT_CENTERED-ROUND_AND_REGULAR-PUNCTATE'
df.loc[df['calc_type'] == 'ROUND_AND_REGULAR-LUCENT_CENTER', 'calc_type'] = 'ROUND_AND_REGULAR-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'LUCENT_CENTER-PUNCTATE', 'calc_type'] = 'LUCENT_CENTERED-PUNCTATE'
df.loc[df['calc_type'] == 'COARSE-ROUND_AND_REGULAR-LUCENT_CENTER', 'calc_type'] = 'COARSE-ROUND_AND_REGULAR-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'ROUND_AND_REGULAR-LUCENT_CENTER-PUNCTATE', 'calc_type'] = 'ROUND_AND_REGULAR-LUCENT_CENTERED-PUNCTATE'
df.loc[df['calc_type'] == 'COARSE-LUCENT_CENTER', 'calc_type'] = 'COARSE-LUCENT_CENTERED'
df.loc[df['calc_type'] == 'PLEOMORPHIC-PLEOMORPHIC', 'calc_type'] = 'PLEOMORPHIC'

# %% [markdown]
# ## Impute Missing Values
# Multiple Imputation by Chained Equations (MICE) is a robust, informative method of estimating missing values in datasets. The procedure imputes missing data through an iterative series of predictive models which estimate the value of missing data using the other variables in the dataset. For this, we'll use our CaseImputer which wraps scikit-learn's IterativeImputer implementation of MICE.
#
# First, let's capture the missing values as we will inspect them after imputation.

# %%
# Grab rows with missing data
null_mask = df.isnull().any(axis=1)
df_missing = df[null_mask]
msg = f"There are {df_missing.shape[0]} rows (approximately {round(df_missing.shape[0] / df_orig.shape[0] * 100,1)}% of the dataset) with missing data in the dataset."
print(msg)
# Out:
# There are 527 rows (approximately 14.8% of the dataset) with missing data in the dataset.

# %%
imp = CBISImputer(random_state=5)
imp.fit(df=df)
df_clean = imp.transform(df=df)

# %% [markdown]
# With that, let's save the data.

# %%
os.makedirs(os.path.dirname(FP_CLEAN), exist_ok=True)
df_clean.to_csv(FP_CLEAN, index=False)

# %% [markdown]
# ## Random Sample Inspection

# %% [markdown]
# Let's take a look at a random sampling of the missing data and compare.

# %%
sample_cases = df_missing['mmg_id'].sample(5)
df_missing.loc[df_missing['mmg_id'].isin(sample_cases)]
df_clean.loc[df_clean['mmg_id'].isin(sample_cases)]
# Out:
#      patient_id  breast_density laterality image_view  abnormality_id  \
# 350     P_00476            2.00      RIGHT        MLO               1
# 351     P_00476            2.00      RIGHT        MLO               2
# 352     P_00476            2.00      RIGHT        MLO               3
# 370     P_00505            1.00       LEFT         CC               1
# 385     P_00510            2.00       LEFT        MLO               1
# 386     P_00510            2.00       LEFT        MLO               3
# 1207    P_01563            3.00       LEFT         CC               1
# 1208    P_01563            3.00       LEFT         CC               2
# 1302    P_01700            1.00       LEFT         CC               1
#
#      abnormality_type                          calc_type calc_distribution  \
# 350     calcification                    LUCENT_CENTERED               NaN
# 351     calcification                    LUCENT_CENTERED               NaN
# 352     calcification                    LUCENT_CENTERED               NaN
# 370     calcification                    LUCENT_CENTERED               NaN
# 385     calcification         ROUND_AND_REGULAR-PUNCTATE               NaN
# 386     calcification                           VASCULAR               NaN
# 1207    calcification  ROUND_AND_REGULAR-LUCENT_CENTERED               NaN
# 1208    calcification  ROUND_AND_REGULAR-LUCENT_CENTERED               NaN
# 1302    calcification                             COARSE               NaN
#
#       assessment                pathology  ...  rows  cols aspect_ratio  \
# 350            2  BENIGN_WITHOUT_CALLBACK  ...  5768  4032         0.70
# 351            2  BENIGN_WITHOUT_CALLBACK  ...  5768  4032         0.70
# 352            2  BENIGN_WITHOUT_CALLBACK  ...  5768  4032         0.70
# 370            2  BENIGN_WITHOUT_CALLBACK  ...  4440  3224         0.73
# 385            2  BENIGN_WITHOUT_CALLBACK  ...  5680  4168         0.73
# 386            2  BENIGN_WITHOUT_CALLBACK  ...  5680  4168         0.73
# 1207           2  BENIGN_WITHOUT_CALLBACK  ...  4536  3016         0.66
# 1208           2  BENIGN_WITHOUT_CALLBACK  ...  4536  3016         0.66
# 1302           2  BENIGN_WITHOUT_CALLBACK  ...  5696  4008         0.70
#
#           size file_size  min_pixel_value  max_pixel_value  mean_pixel_value  \
# 350   23256576  46514254                0            65535         14,498.95
# 351   23256576  46514254                0            65535         14,498.95
# 352   23256576  46514254                0            65535         14,498.95
# 370   14314560  28630216                0            65535         11,710.45
# 385   23674240  47349578                0            65535         13,635.85
# 386   23674240  47349578                0            65535         13,635.85
# 1207  13680576  27362248                0            65535         14,817.37
# 1208  13680576  27362248                0            65535         14,817.37
# 1302  22829568  45660232                0            65535         10,914.10
#
#       std_pixel_value                                           filepath
# 350         16,846.46  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 351         16,846.46  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 352         16,846.46  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 370         14,551.12  data/image/0_raw/CBIS-DDSM/Calc-Training_P_005...
# 385         15,862.98  data/image/0_raw/CBIS-DDSM/Calc-Training_P_005...
# 386         15,862.98  data/image/0_raw/CBIS-DDSM/Calc-Training_P_005...
# 1207        18,352.81  data/image/0_raw/CBIS-DDSM/Calc-Training_P_015...
# 1208        18,352.81  data/image/0_raw/CBIS-DDSM/Calc-Training_P_015...
# 1302        15,386.05  data/image/0_raw/CBIS-DDSM/Calc-Training_P_017...
#
# [9 rows x 27 columns]
#      patient_id  breast_density laterality image_view  abnormality_id  \
# 350     P_00476            2.00      RIGHT        MLO               1
# 351     P_00476            2.00      RIGHT        MLO               2
# 352     P_00476            2.00      RIGHT        MLO               3
# 370     P_00505            1.00       LEFT         CC               1
# 385     P_00510            2.00       LEFT        MLO               1
# 386     P_00510            2.00       LEFT        MLO               3
# 1207    P_01563            3.00       LEFT         CC               1
# 1208    P_01563            3.00       LEFT         CC               2
# 1302    P_01700            1.00       LEFT         CC               1
#
#      abnormality_type                          calc_type calc_distribution  \
# 350     calcification                    LUCENT_CENTERED         SEGMENTAL
# 351     calcification                    LUCENT_CENTERED         SEGMENTAL
# 352     calcification                    LUCENT_CENTERED         SEGMENTAL
# 370     calcification                    LUCENT_CENTERED         SEGMENTAL
# 385     calcification         ROUND_AND_REGULAR-PUNCTATE         SEGMENTAL
# 386     calcification                           VASCULAR         SEGMENTAL
# 1207    calcification  ROUND_AND_REGULAR-LUCENT_CENTERED         SEGMENTAL
# 1208    calcification  ROUND_AND_REGULAR-LUCENT_CENTERED         SEGMENTAL
# 1302    calcification                             COARSE         SEGMENTAL
#
#       assessment                pathology  ...  rows  cols aspect_ratio  \
# 350            2  BENIGN_WITHOUT_CALLBACK  ...  5768  4032         1.00
# 351            2  BENIGN_WITHOUT_CALLBACK  ...  5768  4032         1.00
# 352            2  BENIGN_WITHOUT_CALLBACK  ...  5768  4032         1.00
# 370            2  BENIGN_WITHOUT_CALLBACK  ...  4440  3224         1.00
# 385            2  BENIGN_WITHOUT_CALLBACK  ...  5680  4168         1.00
# 386            2  BENIGN_WITHOUT_CALLBACK  ...  5680  4168         1.00
# 1207           2  BENIGN_WITHOUT_CALLBACK  ...  4536  3016         1.00
# 1208           2  BENIGN_WITHOUT_CALLBACK  ...  4536  3016         1.00
# 1302           2  BENIGN_WITHOUT_CALLBACK  ...  5696  4008         1.00
#
#           size file_size  min_pixel_value  max_pixel_value  mean_pixel_value  \
# 350   23256576  46514254                0            65535         14,499.00
# 351   23256576  46514254                0            65535         14,499.00
# 352   23256576  46514254                0            65535         14,499.00
# 370   14314560  28630216                0            65535         11,710.00
# 385   23674240  47349578                0            65535         13,636.00
# 386   23674240  47349578                0            65535         13,636.00
# 1207  13680576  27362248                0            65535         14,817.00
# 1208  13680576  27362248                0            65535         14,817.00
# 1302  22829568  45660232                0            65535         10,914.00
#
#       std_pixel_value                                           filepath
# 350         16,846.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 351         16,846.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 352         16,846.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_004...
# 370         14,551.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_005...
# 385         15,863.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_005...
# 386         15,863.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_005...
# 1207        18,353.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_015...
# 1208        18,353.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_015...
# 1302        15,386.00  data/image/0_raw/CBIS-DDSM/Calc-Training_P_017...
#
# [9 rows x 27 columns]

# %% [markdown]
# ## Data Quality Analysis 2.0
# Ok, let's have another go at the data quality analysis.

# %% [markdown]
# ### Completeness Analysis

# %%
ds = CBISDataset(filepath=FP_CLEAN)
dqcc = ds.dqa.analyze_completeness()
print(dqcc.summary)
# Out:
#                           Completeness
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                 Complete Records | 3568
#              Record Completeness | 1.0
#                      Data Values | 96336
#             Complete Data Values | 96336
#          Data Value Completeness | 1.0

# %% [markdown]
# We're complete.

# %% [markdown]
# ### Uniqueness Analysis

# %%
dqcu = ds.dqa.analyze_uniqueness()
print(dqcu.summary)
# Out:
#                            Uniqueness
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                   Unique Records | 3568
#                Record Uniqueness | 1.0
#                      Data Values | 96336
#               Unique Data Values | 19864
#            Data Value Uniqueness | 0.206

# %% [markdown]
# We're unique.

# %% [markdown]
# ### Validity Analysis

# %%
dqcv = ds.dqa.analyze_validity()
print(dqcv.summary)
# Out:
#                             Validity
#                          Dataset | CBIS-DDSM
#                          Records | 3568
#                    Valid Records | 3568
#                  Record Validity | 1.0
#                      Data Values | 96336
#                Valid Data Values | 96336
#              Data Value Validity | 1.0

# %% [markdown]
# We're valid. That concludes this data cleaning section.
