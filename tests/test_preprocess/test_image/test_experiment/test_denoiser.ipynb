# %% [markdown]
# # Denoiser Experiment Visualization Test

# %%
from bcd.preprocess.image.experiment.visualize import VisualizeDenoiserResults

# %%
RESULTS_FILEPATH = "data/image/2_exp/results.csv"
SOURCE_IMAGE_DIR = "data/image/2_exp"

# %% [markdown]
# ## Plot Results

# %%
viz = VisualizeDenoiserResults(results_filepath=RESULTS_FILEPATH, source_image_dir=SOURCE_IMAGE_DIR)
viz.plot_results()

# %% [markdown]
# ## Plot Best Result by MSE

# %%
viz.plot_images(metric='mse')

# %% [markdown]
# ## Plot Best Result by PSNR

# %%
viz.plot_images(metric='psnr')

# %% [markdown]
# ## Plot Best Result by SSIM

# %%
viz.plot_images(metric='ssim')
